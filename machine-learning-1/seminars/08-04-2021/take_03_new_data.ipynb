# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import keras

# %% [markdown]
# https://keras.io/examples/timeseries/timeseries_weather_forecasting/

# %%
from zipfile import ZipFile
import os

uri = "https://storage.googleapis.com/tensorflow/tf-keras-datasets/jena_climate_2009_2016.csv.zip"
zip_path = keras.utils.get_file(origin=uri, fname="jena_climate_2009_2016.csv.zip")
zip_file = ZipFile(zip_path)
zip_file.extractall()
csv_path = "jena_climate_2009_2016.csv"

df = pd.read_csv(csv_path)

# %%
# !head {csv_path}
# Out:
# "Date Time","p (mbar)","T (degC)","Tpot (K)","Tdew (degC)","rh (%)","VPmax (mbar)","VPact (mbar)","VPdef (mbar)","sh (g/kg)","H2OC (mmol/mol)","rho (g/m**3)","wv (m/s)","max. wv (m/s)","wd (deg)"
# 01.01.2009 00:10:00,996.52,-8.02,265.40,-8.90,93.30,3.33,3.11,0.22,1.94,3.12,1307.75,1.03,1.75,152.30
# 01.01.2009 00:20:00,996.57,-8.41,265.01,-9.28,93.40,3.23,3.02,0.21,1.89,3.03,1309.80,0.72,1.50,136.10
# 01.01.2009 00:30:00,996.53,-8.51,264.91,-9.31,93.90,3.21,3.01,0.20,1.88,3.02,1310.24,0.19,0.63,171.60
# 01.01.2009 00:40:00,996.51,-8.31,265.12,-9.07,94.20,3.26,3.07,0.19,1.92,3.08,1309.19,0.34,0.50,198.00
# 01.01.2009 00:50:00,996.51,-8.27,265.15,-9.04,94.10,3.27,3.08,0.19,1.92,3.09,1309.00,0.32,0.63,214.30
# 01.01.2009 01:00:00,996.50,-8.05,265.38,-8.78,94.40,3.33,3.14,0.19,1.96,3.15,1307.86,0.21,0.63,192.70
# 01.01.2009 01:10:00,996.50,-7.62,265.81,-8.30,94.80,3.44,3.26,0.18,2.04,3.27,1305.68,0.18,0.63,166.50
# 01.01.2009 01:20:00,996.50,-7.62,265.81,-8.36,94.40,3.44,3.25,0.19,2.03,3.26,1305.69,0.19,0.50,118.60
# 01.01.2009 01:30:00,996.50,-7.91,265.52,-8.73,93.80,3.36,3.15,0.21,1.97,3.16,1307.17,0.28,0.75,188.50

# %%
weather_df = pd.read_csv(csv_path)

# %%
weather_df.head()
# Out:
#              Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0  01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90    93.3
# 1  01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28    93.4
# 2  01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31    93.9
# 3  01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07    94.2
# 4  01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04    94.1
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  \
# 0          3.33          3.11          0.22       1.94             3.12
# 1          3.23          3.02          0.21       1.89             3.03
# 2          3.21          3.01          0.20       1.88             3.02
# 3          3.26          3.07          0.19       1.92             3.08
# 4          3.27          3.08          0.19       1.92             3.09
#
#    rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 0       1307.75      1.03           1.75     152.3
# 1       1309.80      0.72           1.50     136.1
# 2       1310.24      0.19           0.63     171.6
# 3       1309.19      0.34           0.50     198.0
# 4       1309.00      0.32           0.63     214.3

# %%
weather_df.tail()
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 420546  31.12.2016 23:20:00   1000.07     -4.05    269.10        -8.13
# 420547  31.12.2016 23:30:00    999.93     -3.35    269.81        -8.06
# 420548  31.12.2016 23:40:00    999.82     -3.16    270.01        -8.21
# 420549  31.12.2016 23:50:00    999.81     -4.23    268.94        -8.53
# 420550  01.01.2017 00:00:00    999.82     -4.82    268.36        -8.42
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# 420546   73.10          4.52          3.30          1.22       2.06
# 420547   69.71          4.77          3.32          1.44       2.07
# 420548   67.91          4.84          3.28          1.55       2.05
# 420549   71.80          4.46          3.20          1.26       1.99
# 420550   75.70          4.27          3.23          1.04       2.01
#
#         H2OC (mmol/mol)  rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 420546             3.30       1292.98      0.67           1.52     240.0
# 420547             3.32       1289.44      1.14           1.92     234.3
# 420548             3.28       1288.39      1.08           2.00     215.2
# 420549             3.20       1293.56      1.49           2.16     225.8
# 420550             3.23       1296.38      1.23           1.96     184.9

# %%
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420551 entries, 0 to 420550
# Data columns (total 15 columns):
# Date Time          420551 non-null object
# p (mbar)           420551 non-null float64
# T (degC)           420551 non-null float64
# Tpot (K)           420551 non-null float64
# Tdew (degC)        420551 non-null float64
# rh (%)             420551 non-null float64
# VPmax (mbar)       420551 non-null float64
# VPact (mbar)       420551 non-null float64
# VPdef (mbar)       420551 non-null float64
# sh (g/kg)          420551 non-null float64
# H2OC (mmol/mol)    420551 non-null float64
# rho (g/m**3)       420551 non-null float64
# wv (m/s)           420551 non-null float64
# max. wv (m/s)      420551 non-null float64
# wd (deg)           420551 non-null float64
# dtypes: float64(14), object(1)
# memory usage: 48.1+ MB

# %%
weather_df["dt_gen_h1_pred"] = pd.to_datetime(weather_df["Date Time"], format="%d.%m.%Y %H:%M:%S")

# %%
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420551 entries, 0 to 420550
# Data columns (total 16 columns):
# Date Time          420551 non-null object
# p (mbar)           420551 non-null float64
# T (degC)           420551 non-null float64
# Tpot (K)           420551 non-null float64
# Tdew (degC)        420551 non-null float64
# rh (%)             420551 non-null float64
# VPmax (mbar)       420551 non-null float64
# VPact (mbar)       420551 non-null float64
# VPdef (mbar)       420551 non-null float64
# sh (g/kg)          420551 non-null float64
# H2OC (mmol/mol)    420551 non-null float64
# rho (g/m**3)       420551 non-null float64
# wv (m/s)           420551 non-null float64
# max. wv (m/s)      420551 non-null float64
# wd (deg)           420551 non-null float64
# dt_gen_h1_pred     420551 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(14), object(1)
# memory usage: 51.3+ MB

# %% [markdown]
# Будем предсказывать температуру через 10 минут

# %%
weather_df_daliy = weather_df.set_index("dt_gen_h1_pred").resample('D').max().reset_index()

# %%
weather_df_daliy["value_at_gentime"] = weather_df_daliy["T (degC)"]

# %%
del weather_df_daliy["Date Time"]
del weather_df_daliy["T (degC)"]

# %%
weather_df_daliy
# Out:
#      dt_gen_h1_pred  p (mbar)  Tpot (K)  Tdew (degC)  rh (%)  VPmax (mbar)  \
# 0        2009-01-01   1000.87    269.00        -5.36    94.8          4.48
# 1        2009-01-02   1002.65    271.12        -3.88    96.3          5.22
# 2        2009-01-03   1002.49    272.59        -6.09    93.9          5.75
# 3        2009-01-04    992.93    273.55        -2.26    93.9          5.83
# 4        2009-01-05    997.54    272.89        -2.45    93.2          5.49
# ...             ...       ...       ...          ...     ...           ...
# 2918     2016-12-28   1015.35    278.53         3.11    91.9          9.55
# 2919     2016-12-29   1015.21    276.65         2.43    98.1          8.46
# 2920     2016-12-30   1012.55    276.11         2.97    98.2          7.95
# 2921     2016-12-31   1008.67    278.12        -3.04    91.8          8.86
# 2922     2017-01-01    999.82    268.36        -8.42    75.7          4.27
#
#       VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# 0             4.09          0.49       2.55             4.09       1318.81
# 1             4.58          0.70       2.86             4.59       1298.51
# 2             3.87          2.86       2.41             3.86       1323.70
# 3             5.17          1.53       3.27             5.25       1274.06
# 4             5.10          0.83       3.23             5.18       1332.38
# ...            ...           ...        ...              ...           ...
# 2918          7.64          2.19       4.70             7.54       1275.20
# 2919          7.28          1.79       4.47             7.17       1297.30
# 2920          7.56          1.70       4.67             7.49       1312.47
# 2921          4.88          4.03       3.03             4.86       1314.79
# 2922          3.23          1.04       2.01             3.23       1296.38
#
#       wv (m/s)  max. wv (m/s)  wd (deg)  value_at_gentime
# 0         2.51           3.63     357.9             -4.17
# 1         3.87           6.13     358.8             -2.12
# 2         3.64           4.88     357.2             -0.82
# 3         3.95           7.13     257.0             -0.63
# 4         7.81          10.88     358.9             -1.44
# ...        ...            ...       ...               ...
# 2918      4.08           7.45     348.3              6.29
# 2919      2.04           2.80     344.8              4.55
# 2920      2.20           3.77     282.7              3.67
# 2921      1.49           2.75     333.3              5.21
# 2922      1.23           1.96     184.9             -4.82
#
# [2923 rows x 15 columns]

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
weather_df_daliy["target_value"] = weather_df_daliy.value_at_gentime.shift(-1).fillna(0)
weather_df_daliy["dt_target"] = weather_df_daliy.dt_gen_h1_pred.shift(-1)

weather_df_daliy = weather_df_daliy.iloc[0:2855,:].copy()
# за 2016-10-26 и 2016-10-27 нет данных

# %%
plt.plot(weather_df_daliy["dt_gen_h1_pred"], weather_df_daliy.value_at_gentime)
plt.grid(True)

# %%
weather_df_daliy.head()
# Out:
#   dt_gen_h1_pred  p (mbar)  Tpot (K)  Tdew (degC)  rh (%)  VPmax (mbar)  \
# 0     2009-01-01   1000.87    269.00        -5.36    94.8          4.48
# 1     2009-01-02   1002.65    271.12        -3.88    96.3          5.22
# 2     2009-01-03   1002.49    272.59        -6.09    93.9          5.75
# 3     2009-01-04    992.93    273.55        -2.26    93.9          5.83
# 4     2009-01-05    997.54    272.89        -2.45    93.2          5.49
#
#    VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# 0          4.09          0.49       2.55             4.09       1318.81
# 1          4.58          0.70       2.86             4.59       1298.51
# 2          3.87          2.86       2.41             3.86       1323.70
# 3          5.17          1.53       3.27             5.25       1274.06
# 4          5.10          0.83       3.23             5.18       1332.38
#
#    wv (m/s)  max. wv (m/s)  wd (deg)  value_at_gentime  target_value  \
# 0      2.51           3.63     357.9             -4.17         -2.12
# 1      3.87           6.13     358.8             -2.12         -0.82
# 2      3.64           4.88     357.2             -0.82         -0.63
# 3      3.95           7.13     257.0             -0.63         -1.44
# 4      7.81          10.88     358.9             -1.44        -10.88
#
#    dt_target
# 0 2009-01-02
# 1 2009-01-03
# 2 2009-01-04
# 3 2009-01-05
# 4 2009-01-06

# %%
weather_df_daliy.tail(7)
# Out:
#      dt_gen_h1_pred  p (mbar)  Tpot (K)  Tdew (degC)  rh (%)  VPmax (mbar)  \
# 2848     2016-10-19    990.89    284.31         8.42    96.1         12.36
# 2849     2016-10-20    987.30    283.57         5.13    95.7         11.74
# 2850     2016-10-21    987.57    283.39         4.89    95.3         11.59
# 2851     2016-10-22    988.69    281.76         5.78    97.0         10.38
# 2852     2016-10-23    989.06    284.11         6.14    98.7         12.24
# 2853     2016-10-24    989.41    283.24         8.66    98.5         11.54
# 2854     2016-10-25    994.76    283.07         8.35    98.6         11.87
#
#       VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# 2848         11.05          4.25       6.98            11.17       1228.47
# 2849          8.81          3.72       5.57             8.93       1230.43
# 2850          8.66          3.49       5.47             8.77       1232.41
# 2851          9.22          1.87       5.83             9.34       1236.99
# 2852          9.45          3.13       5.97             9.57       1238.98
# 2853         11.23          1.41       7.11            11.38       1230.65
# 2854         11.00          0.90       6.91            11.06       1224.99
#
#       wv (m/s)  max. wv (m/s)  wd (deg)  value_at_gentime  target_value  \
# 2848      5.24           8.41     347.7             10.08          9.31
# 2849      3.68           5.67     359.1              9.31          9.13
# 2850      4.64           6.81     356.7              9.13          7.50
# 2851      1.99           4.16     342.7              7.50          9.94
# 2852      2.64           3.84     350.5              9.94          9.06
# 2853      3.21           4.53     356.5              9.06          9.48
# 2854      1.74           3.80     359.5              9.48          0.00
#
#       dt_target
# 2848 2016-10-20
# 2849 2016-10-21
# 2850 2016-10-22
# 2851 2016-10-23
# 2852 2016-10-24
# 2853 2016-10-25
# 2854 2016-10-26

# %%
from argparse import Namespace

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, median_absolute_error

# %%
weather_df_daliy["target_value"].isna().value_counts()
# Out:
# False    2855
# Name: target_value, dtype: int64

# %%
weather_df_daliy["value_at_gentime"].isna().value_counts()
# Out:
# False    2855
# Name: value_at_gentime, dtype: int64

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    error = y_pred - y_true
    ae = np.abs(error)
    return np.sum(ae) / np.sum(np.abs(y_true))

# %%
def quality(df, pred_name, target_name="target_value"):
    quality = Namespace()
    
    quality.prediction_name = pred_name
    y_true = df[target_name]
    y_pred = df[pred_name]
    
    quality.rmse = np.sqrt(mean_squared_error(y_true=y_true, y_pred=y_pred))
    
    quality.mae = mean_absolute_error(y_true=y_true, y_pred=y_pred)
    quality.mape = mean_absolute_percentage_error(y_true=y_true, y_pred=y_pred)
    quality.median_ae = median_absolute_error(y_true=y_true, y_pred=y_pred)
    
    return quality

# %%
q_inertial = quality(
    df = weather_df_daliy,
    pred_name="value_at_gentime"
)

# %%
q_inertial
# Out:
# Namespace(mae=2.615338003502627, mape=0.18215681491059013, median_ae=2.1000000000000014, prediction_name='value_at_gentime', rmse=3.4089110329873846)

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.TimeSeriesSplit.html

# %%
from sklearn.model_selection import TimeSeriesSplit

# %%
ts_cv_1 = TimeSeriesSplit(n_splits = 5, max_train_size=1000,test_size=300, gap=5)

# %%
def show_splits(tss, df):
    plt.figure(figsize=(10,7))
    plt.plot(df["dt_target"], np.ones_like(df["dt_target"], "int") *  -1)

    for n, (train_index, test_index) in enumerate(tss.split(X=df.loc[:,["target_value"]])):
        X_train = df.loc[:,["target_value"]].iloc[train_index]
        X_test = df.loc[:,["target_value"]].iloc[test_index]

        y_train = df.target_value.iloc[train_index]
        y_test = df.target_value.iloc[test_index]

        dt_train = df["dt_target"].iloc[train_index]
        dt_test = df["dt_target"].iloc[test_index]


        plt.plot(dt_train, np.ones_like(dt_train, "int") * n)
        plt.plot(dt_test, np.ones_like(dt_test, "int") * n)
        plt.grid(True)

    plt.show()

# %%
show_splits(ts_cv_1, df= weather_df_daliy)

# %%
ts_cv_2 = TimeSeriesSplit(n_splits = 5, max_train_size=150,test_size=25, gap=5)

# %%
show_splits(ts_cv_2,  df= weather_df_daliy)

# %%
ts_cv_3 = TimeSeriesSplit(n_splits = 5, max_train_size=None,test_size=250, gap=5)

# %%
show_splits(ts_cv_3,  df= weather_df_daliy)

# %%
# Feature Engineering

# %%
weather_df_daliy
# Out:
#      dt_gen_h1_pred  p (mbar)  Tpot (K)  Tdew (degC)  rh (%)  VPmax (mbar)  \
# 0        2009-01-01   1000.87    269.00        -5.36    94.8          4.48
# 1        2009-01-02   1002.65    271.12        -3.88    96.3          5.22
# 2        2009-01-03   1002.49    272.59        -6.09    93.9          5.75
# 3        2009-01-04    992.93    273.55        -2.26    93.9          5.83
# 4        2009-01-05    997.54    272.89        -2.45    93.2          5.49
# ...             ...       ...       ...          ...     ...           ...
# 2850     2016-10-21    987.57    283.39         4.89    95.3         11.59
# 2851     2016-10-22    988.69    281.76         5.78    97.0         10.38
# 2852     2016-10-23    989.06    284.11         6.14    98.7         12.24
# 2853     2016-10-24    989.41    283.24         8.66    98.5         11.54
# 2854     2016-10-25    994.76    283.07         8.35    98.6         11.87
#
#       VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# 0             4.09          0.49       2.55             4.09       1318.81
# 1             4.58          0.70       2.86             4.59       1298.51
# 2             3.87          2.86       2.41             3.86       1323.70
# 3             5.17          1.53       3.27             5.25       1274.06
# 4             5.10          0.83       3.23             5.18       1332.38
# ...            ...           ...        ...              ...           ...
# 2850          8.66          3.49       5.47             8.77       1232.41
# 2851          9.22          1.87       5.83             9.34       1236.99
# 2852          9.45          3.13       5.97             9.57       1238.98
# 2853         11.23          1.41       7.11            11.38       1230.65
# 2854         11.00          0.90       6.91            11.06       1224.99
#
#       wv (m/s)  max. wv (m/s)  wd (deg)  value_at_gentime  target_value  \
# 0         2.51           3.63     357.9             -4.17         -2.12
# 1         3.87           6.13     358.8             -2.12         -0.82
# 2         3.64           4.88     357.2             -0.82         -0.63
# 3         3.95           7.13     257.0             -0.63         -1.44
# 4         7.81          10.88     358.9             -1.44        -10.88
# ...        ...            ...       ...               ...           ...
# 2850      4.64           6.81     356.7              9.13          7.50
# 2851      1.99           4.16     342.7              7.50          9.94
# 2852      2.64           3.84     350.5              9.94          9.06
# 2853      3.21           4.53     356.5              9.06          9.48
# 2854      1.74           3.80     359.5              9.48          0.00
#
#       dt_target
# 0    2009-01-02
# 1    2009-01-03
# 2    2009-01-04
# 3    2009-01-05
# 4    2009-01-06
# ...         ...
# 2850 2016-10-22
# 2851 2016-10-23
# 2852 2016-10-24
# 2853 2016-10-25
# 2854 2016-10-26
#
# [2855 rows x 17 columns]

# %% [markdown]
# https://tsfresh.com/

# %%
#0.17.0

# %%
from tsfresh import extract_relevant_features, extract_features
#from tsfresh.examples.robot_execution_failures import load_robot_execution_failures

# %%
data = []
window_len = 90
for n in range(window_len, len(weather_df_daliy)+1):
    frame = weather_df_daliy.reset_index().iloc[n-window_len:n,:].copy()
    frame["id"] = n
    data.append(frame)

# %%
len(data)
# Out:
# 2766

# %%
weather_df_daliy
# Out:
#      dt_gen_h1_pred  p (mbar)  Tpot (K)  Tdew (degC)  rh (%)  VPmax (mbar)  \
# 0        2009-01-01   1000.87    269.00        -5.36    94.8          4.48
# 1        2009-01-02   1002.65    271.12        -3.88    96.3          5.22
# 2        2009-01-03   1002.49    272.59        -6.09    93.9          5.75
# 3        2009-01-04    992.93    273.55        -2.26    93.9          5.83
# 4        2009-01-05    997.54    272.89        -2.45    93.2          5.49
# ...             ...       ...       ...          ...     ...           ...
# 2850     2016-10-21    987.57    283.39         4.89    95.3         11.59
# 2851     2016-10-22    988.69    281.76         5.78    97.0         10.38
# 2852     2016-10-23    989.06    284.11         6.14    98.7         12.24
# 2853     2016-10-24    989.41    283.24         8.66    98.5         11.54
# 2854     2016-10-25    994.76    283.07         8.35    98.6         11.87
#
#       VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# 0             4.09          0.49       2.55             4.09       1318.81
# 1             4.58          0.70       2.86             4.59       1298.51
# 2             3.87          2.86       2.41             3.86       1323.70
# 3             5.17          1.53       3.27             5.25       1274.06
# 4             5.10          0.83       3.23             5.18       1332.38
# ...            ...           ...        ...              ...           ...
# 2850          8.66          3.49       5.47             8.77       1232.41
# 2851          9.22          1.87       5.83             9.34       1236.99
# 2852          9.45          3.13       5.97             9.57       1238.98
# 2853         11.23          1.41       7.11            11.38       1230.65
# 2854         11.00          0.90       6.91            11.06       1224.99
#
#       wv (m/s)  max. wv (m/s)  wd (deg)  value_at_gentime  target_value  \
# 0         2.51           3.63     357.9             -4.17         -2.12
# 1         3.87           6.13     358.8             -2.12         -0.82
# 2         3.64           4.88     357.2             -0.82         -0.63
# 3         3.95           7.13     257.0             -0.63         -1.44
# 4         7.81          10.88     358.9             -1.44        -10.88
# ...        ...            ...       ...               ...           ...
# 2850      4.64           6.81     356.7              9.13          7.50
# 2851      1.99           4.16     342.7              7.50          9.94
# 2852      2.64           3.84     350.5              9.94          9.06
# 2853      3.21           4.53     356.5              9.06          9.48
# 2854      1.74           3.80     359.5              9.48          0.00
#
#       dt_target
# 0    2009-01-02
# 1    2009-01-03
# 2    2009-01-04
# 3    2009-01-05
# 4    2009-01-06
# ...         ...
# 2850 2016-10-22
# 2851 2016-10-23
# 2852 2016-10-24
# 2853 2016-10-25
# 2854 2016-10-26
#
# [2855 rows x 17 columns]

# %%
data[1]
# Out:
#     index dt_gen_h1_pred  p (mbar)  Tpot (K)  Tdew (degC)  rh (%)  \
# 1       1     2009-01-02   1002.65    271.12        -3.88    96.3
# 2       2     2009-01-03   1002.49    272.59        -6.09    93.9
# 3       3     2009-01-04    992.93    273.55        -2.26    93.9
# 4       4     2009-01-05    997.54    272.89        -2.45    93.2
# 5       5     2009-01-06    998.49    262.51       -15.07    89.3
# ..    ...            ...       ...       ...          ...     ...
# 86     86     2009-03-28    977.02    284.55         3.68    87.9
# 87     87     2009-03-29    987.04    283.54         1.91    83.0
# 88     88     2009-03-30    997.17    281.89         2.02    89.6
# 89     89     2009-03-31    998.62    285.32         2.40    97.5
# 90     90     2009-04-01    994.64    287.12         1.33    93.6
#
#     VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  \
# 1           5.22          4.58          0.70       2.86             4.59
# 2           5.75          3.87          2.86       2.41             3.86
# 3           5.83          5.17          1.53       3.27             5.25
# 4           5.49          5.10          0.83       3.23             5.18
# 5           2.66          1.89          0.87       1.18             1.89
# ..           ...           ...           ...        ...              ...
# 86         11.47          7.96          4.16       5.11             8.20
# 87         11.38          7.01          5.68       4.46             7.15
# 88         10.94          7.07          4.48       4.44             7.11
# 89         13.82          7.26          7.82       4.54             7.28
# 90         15.38          6.72          9.21       4.22             6.76
#
#     rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)  value_at_gentime  \
# 1        1298.51      3.87           6.13     358.8             -2.12
# 2        1323.70      3.64           4.88     357.2             -0.82
# 3        1274.06      3.95           7.13     257.0             -0.63
# 4        1332.38      7.81          10.88     358.9             -1.44
# 5        1374.18      3.42           4.50     358.7            -10.88
# ..           ...       ...            ...       ...               ...
# 86       1228.66      9.36          13.63     263.2              8.97
# 87       1234.63      4.46           7.00     359.8              8.85
# 88       1266.20      3.81           5.88     357.1              8.27
# 89       1282.53      4.15           6.88     343.7             11.76
# 90       1273.70      6.48          11.38     349.9             13.38
#
#     target_value  dt_target  id
# 1          -0.82 2009-01-03  91
# 2          -0.63 2009-01-04  91
# 3          -1.44 2009-01-05  91
# 4         -10.88 2009-01-06  91
# 5          -7.45 2009-01-07  91
# ..           ...        ...  ..
# 86          8.85 2009-03-29  91
# 87          8.27 2009-03-30  91
# 88         11.76 2009-03-31  91
# 89         13.38 2009-04-01  91
# 90         16.28 2009-04-02  91
#
# [90 rows x 19 columns]

# %%
expanded_df = pd.concat(data)

# %%
y = pd.DataFrame(
    [
        {
            "target": chunk.target_value.iloc[-1], 
            "id": chunk["id"].iloc[-1],
            "value_at_gentime": chunk["value_at_gentime"].iloc[-1]
        } for chunk in data
    ]
)

# %%
y.set_index("id")["target"]
# Out:
# id
# 90      13.38
# 91      16.28
# 92      22.37
# 93      19.58
# 94      14.39
#         ...
# 2851     7.50
# 2852     9.94
# 2853     9.06
# 2854     9.48
# 2855     0.00
# Name: target, Length: 2766, dtype: float64

# %%
expanded_df
# Out:
#       index dt_gen_h1_pred  p (mbar)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0         0     2009-01-01   1000.87    269.00        -5.36    94.8
# 1         1     2009-01-02   1002.65    271.12        -3.88    96.3
# 2         2     2009-01-03   1002.49    272.59        -6.09    93.9
# 3         3     2009-01-04    992.93    273.55        -2.26    93.9
# 4         4     2009-01-05    997.54    272.89        -2.45    93.2
# ...     ...            ...       ...       ...          ...     ...
# 2850   2850     2016-10-21    987.57    283.39         4.89    95.3
# 2851   2851     2016-10-22    988.69    281.76         5.78    97.0
# 2852   2852     2016-10-23    989.06    284.11         6.14    98.7
# 2853   2853     2016-10-24    989.41    283.24         8.66    98.5
# 2854   2854     2016-10-25    994.76    283.07         8.35    98.6
#
#       VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  \
# 0             4.48          4.09          0.49       2.55             4.09
# 1             5.22          4.58          0.70       2.86             4.59
# 2             5.75          3.87          2.86       2.41             3.86
# 3             5.83          5.17          1.53       3.27             5.25
# 4             5.49          5.10          0.83       3.23             5.18
# ...            ...           ...           ...        ...              ...
# 2850         11.59          8.66          3.49       5.47             8.77
# 2851         10.38          9.22          1.87       5.83             9.34
# 2852         12.24          9.45          3.13       5.97             9.57
# 2853         11.54         11.23          1.41       7.11            11.38
# 2854         11.87         11.00          0.90       6.91            11.06
#
#       rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)  value_at_gentime  \
# 0          1318.81      2.51           3.63     357.9             -4.17
# 1          1298.51      3.87           6.13     358.8             -2.12
# 2          1323.70      3.64           4.88     357.2             -0.82
# 3          1274.06      3.95           7.13     257.0             -0.63
# 4          1332.38      7.81          10.88     358.9             -1.44
# ...            ...       ...            ...       ...               ...
# 2850       1232.41      4.64           6.81     356.7              9.13
# 2851       1236.99      1.99           4.16     342.7              7.50
# 2852       1238.98      2.64           3.84     350.5              9.94
# 2853       1230.65      3.21           4.53     356.5              9.06
# 2854       1224.99      1.74           3.80     359.5              9.48
#
#       target_value  dt_target    id
# 0            -2.12 2009-01-02    90
# 1            -0.82 2009-01-03    90
# 2            -0.63 2009-01-04    90
# 3            -1.44 2009-01-05    90
# 4           -10.88 2009-01-06    90
# ...            ...        ...   ...
# 2850          7.50 2016-10-22  2855
# 2851          9.94 2016-10-23  2855
# 2852          9.06 2016-10-24  2855
# 2853          9.48 2016-10-25  2855
# 2854          0.00 2016-10-26  2855
#
# [248940 rows x 19 columns]

# %%
features = extract_relevant_features(
    expanded_df.loc[:, ["id", "dt_gen_h1_pred", "value_at_gentime"]], 
    y.set_index("id")["target"], 
    column_id="id", column_sort="dt_gen_h1_pred"
)
# Out:
# Feature Extraction: 100%|██████████| 30/30 [00:28<00:00,  1.04it/s]

# %%
features
# Out:
#       value_at_gentime__ar_coefficient__coeff_0__k_10  \
# 90                                           1.147621
# 91                                           0.923388
# 92                                           0.744994
# 93                                           0.358051
# 94                                           0.587773
# ...                                               ...
# 2851                                         0.756833
# 2852                                         0.526269
# 2853                                         0.783985
# 2854                                         0.635506
# 2855                                         0.646973
#
#       value_at_gentime__mean_change  \
# 90                         0.178989
# 91                         0.174157
# 92                         0.192135
# 93                         0.258427
# 94                         0.236180
# ...                             ...
# 2851                      -0.209775
# 2852                      -0.230000
# 2853                      -0.178876
# 2854                      -0.182921
# 2855                      -0.183371
#
#       value_at_gentime__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.0  \
# 90                                             0.178989
# 91                                             0.174157
# 92                                             0.192135
# 93                                             0.258427
# 94                                             0.236180
# ...                                                 ...
# 2851                                          -0.209775
# 2852                                          -0.230000
# 2853                                          -0.178876
# 2854                                          -0.182921
# 2855                                          -0.183371
#
#       value_at_gentime__time_reversal_asymmetry_statistic__lag_1  \
# 90                                            18.691484
# 91                                            33.073160
# 92                                            52.305341
# 93                                           111.772985
# 94                                           143.785584
# ...                                                 ...
# 2851                                        -312.659256
# 2852                                        -282.728598
# 2853                                        -240.210879
# 2854                                        -236.400313
# 2855                                        -217.795436
#
#       value_at_gentime__time_reversal_asymmetry_statistic__lag_2  \
# 90                                            27.700047
# 91                                            37.032159
# 92                                            63.398710
# 93                                           131.531692
# 94                                           179.960833
# ...                                                 ...
# 2851                                        -535.336910
# 2852                                        -521.305378
# 2853                                        -460.668834
# 2854                                        -461.224533
# 2855                                        -452.780528
#
#       value_at_gentime__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.0  \
# 90                                             0.216818
# 91                                             0.188615
# 92                                             0.144154
# 93                                             0.169077
# 94                                             0.192308
# ...                                                 ...
# 2851                                          -0.205077
# 2852                                          -0.311250
# 2853                                          -0.268923
# 2854                                          -0.274462
# 2855                                          -0.275077
#
#       value_at_gentime__time_reversal_asymmetry_statistic__lag_3  \
# 90                                            38.867760
# 91                                            51.897612
# 92                                            71.066872
# 93                                           131.461587
# 94                                           180.462128
# ...                                                 ...
# 2851                                        -717.308240
# 2852                                        -726.023420
# 2853                                        -697.406411
# 2854                                        -654.517189
# 2855                                        -563.099661
#
#       value_at_gentime__agg_linear_trend__attr_"rvalue"__chunk_len_50__f_agg_"mean"  \
# 90                                                  1.0
# 91                                                  1.0
# 92                                                  1.0
# 93                                                  1.0
# 94                                                  1.0
# ...                                                 ...
# 2851                                               -1.0
# 2852                                               -1.0
# 2853                                               -1.0
# 2854                                               -1.0
# 2855                                               -1.0
#
#       value_at_gentime__mean_abs_change  \
# 90                             2.168202
# 91                             2.163371
# 92                             2.181348
# 93                             2.247640
# 94                             2.269888
# ...                                 ...
# 2851                           2.505955
# 2852                           2.522360
# 2853                           2.526067
# 2854                           2.530112
# 2855                           2.529663
#
#       value_at_gentime__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.0  \
# 90                                             2.168202
# 91                                             2.163371
# 92                                             2.181348
# 93                                             2.247640
# 94                                             2.269888
# ...                                                 ...
# 2851                                           2.505955
# 2852                                           2.522360
# 2853                                           2.526067
# 2854                                           2.530112
# 2855                                           2.529663
#
#       ...  value_at_gentime__ar_coefficient__coeff_7__k_10  \
# 90    ...                                        -0.019598
# 91    ...                                        -0.056758
# 92    ...                                        -0.047682
# 93    ...                                         0.000470
# 94    ...                                        -0.009900
# ...   ...                                              ...
# 2851  ...                                         0.088145
# 2852  ...                                         0.088689
# 2853  ...                                         0.089110
# 2854  ...                                         0.069635
# 2855  ...                                         0.065406
#
#       value_at_gentime__fft_coefficient__attr_"abs"__coeff_5  \
# 90                                            78.687657
# 91                                            96.088294
# 92                                           112.821602
# 93                                           130.847703
# 94                                           143.221147
# ...                                                 ...
# 2851                                          93.941726
# 2852                                          94.921063
# 2853                                         104.832942
# 2854                                         119.353637
# 2855                                         135.073907
#
#       value_at_gentime__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"min"  \
# 90                                            -4.242573
# 91                                            -5.261228
# 92                                            -4.159766
# 93                                            -3.954152
# 94                                            -4.190234
# ...                                                 ...
# 2851                                          24.678070
# 2852                                          24.736257
# 2853                                          23.801871
# 2854                                          23.269240
# 2855                                          23.024444
#
#       value_at_gentime__fft_coefficient__attr_"imag"__coeff_41  \
# 90                                             0.352377
# 91                                             3.087120
# 92                                            -1.215710
# 93                                             5.642141
# 94                                            -4.060807
# ...                                                 ...
# 2851                                           0.728605
# 2852                                          -2.662970
# 2853                                          -0.578725
# 2854                                          -0.855125
# 2855                                          -2.148885
#
#       value_at_gentime__fft_coefficient__attr_"real"__coeff_9  \
# 90                                            11.813614
# 91                                            30.521958
# 92                                            34.907865
# 93                                            26.321257
# 94                                             0.841058
# ...                                                 ...
# 2851                                          -5.246364
# 2852                                          23.915427
# 2853                                          49.655761
# 2854                                          60.867797
# 2855                                          52.799393
#
#       value_at_gentime__cwt_coefficients__coeff_13__w_10__widths_(2, 5, 10, 20)  \
# 90                                             0.120552
# 91                                             1.703632
# 92                                             3.205741
# 93                                             4.547388
# 94                                             5.608809
# ...                                                 ...
# 2851                                          25.796104
# 2852                                          24.838468
# 2853                                          24.224797
# 2854                                          23.782979
# 2855                                          23.647967
#
#       value_at_gentime__change_quantiles__f_agg_"var"__isabs_False__qh_0.2__ql_0.0  \
# 90                                             8.903871
# 91                                             8.071556
# 92                                             8.497380
# 93                                             8.849837
# 94                                             8.815467
# ...                                                 ...
# 2851                                           5.242620
# 2852                                           4.993923
# 2853                                           3.983286
# 2854                                           3.784718
# 2855                                           3.180473
#
#       value_at_gentime__number_cwt_peaks__n_5  \
# 90                                        8.0
# 91                                        8.0
# 92                                        8.0
# 93                                        7.0
# 94                                        8.0
# ...                                       ...
# 2851                                     10.0
# 2852                                     10.0
# 2853                                     10.0
# 2854                                     10.0
# 2855                                     11.0
#
#       value_at_gentime__ratio_beyond_r_sigma__r_2  \
# 90                                       0.022222
# 91                                       0.033333
# 92                                       0.033333
# 93                                       0.044444
# 94                                       0.055556
# ...                                           ...
# 2851                                     0.011111
# 2852                                     0.011111
# 2853                                     0.022222
# 2854                                     0.011111
# 2855                                     0.011111
#
#       value_at_gentime__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.4
# 90                                             2.569584
# 91                                             2.295556
# 92                                             2.517856
# 93                                             0.710960
# 94                                             0.284133
# ...                                                 ...
# 2851                                           1.446392
# 2852                                           0.339581
# 2853                                           0.205096
# 2854                                           1.159624
# 2855                                           2.369664
#
# [2766 rows x 436 columns]

# %%
y
# Out:
#       target    id  value_at_gentime
# 0      13.38    90             11.76
# 1      16.28    91             13.38
# 2      22.37    92             16.28
# 3      19.58    93             22.37
# 4      14.39    94             19.58
# ...      ...   ...               ...
# 2761    7.50  2851              9.13
# 2762    9.94  2852              7.50
# 2763    9.06  2853              9.94
# 2764    9.48  2854              9.06
# 2765    0.00  2855              9.48
#
# [2766 rows x 3 columns]

# %%
tss = ts_cv_1
for n, (train_index, test_index) in enumerate(tss.split(X=features)):
        X_train = features.iloc[train_index]
        X_test = features.iloc[test_index]

        y_train =y["target"].iloc[train_index]
        y_train_inertial = y["value_at_gentime"].iloc[train_index]
        
        y_test =y["target"].iloc[test_index]
        y_test_inertial = y["value_at_gentime"].iloc[test_index]

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
clf = RandomForestRegressor(random_state=42)
clf.fit(X_train, y_train)
train_pred = clf.predict(X_train)
test_pred = clf.predict(X_test)
clf_train_q =  quality(
    df=pd.DataFrame(
        {"train_pred": train_pred, "target_value": y_train}
    ), pred_name="train_pred", target_name="target_value")

inertial_train_q =  quality(
    df=pd.DataFrame(
        {"y_train_inertial": y_train_inertial, "target_value": y_train}
    ), pred_name="y_train_inertial", target_name="target_value")



clf_test_q =  quality(
    df=pd.DataFrame(
        {"test_pred": test_pred, "target_value": y_test}
    ), pred_name="test_pred", target_name="target_value")

inertial_test_q =  quality(
    df=pd.DataFrame(
        {"y_test_inertial": y_test_inertial, "target_value": y_test}
    ), pred_name="y_test_inertial", target_name="target_value")

# %%
clf_train_q
# Out:
# Namespace(mae=0.9760635, mape=0.0629431691113596, median_ae=0.7779499999999944, prediction_name='train_pred', rmse=1.247629938920191)

# %%
inertial_train_q
# Out:
# Namespace(mae=2.58166, mape=0.16648287941105533, median_ae=2.1700000000000004, prediction_name='y_train_inertial', rmse=3.3630216770041788)

# %%
clf_test_q
# Out:
# Namespace(mae=3.5115030000000003, mape=0.22221889634223516, median_ae=3.342999999999998, prediction_name='test_pred', rmse=4.207101022640175)

# %%
inertial_test_q
# Out:
# Namespace(mae=2.518066666666667, mape=0.1593511369868793, median_ae=1.9400000000000035, prediction_name='y_test_inertial', rmse=3.266601393905701)

# %%
plt.plot(train_pred)
plt.plot(y_train_inertial.values)
plt.plot(y_train.values)

# %%
plt.plot(test_pred)
plt.plot(y_test_inertial.values)
plt.plot(y_test.values)

# %%
y_test_inertial
# Out:
# 2466    2.92
# 2467    2.72
# 2468    0.40
# 2469    0.03
# 2470   -0.57
#         ...
# 2761    9.13
# 2762    7.50
# 2763    9.94
# 2764    9.06
# 2765    9.48
# Name: value_at_gentime, Length: 300, dtype: float64

# %%
test_pred
# Out:
# array([ 7.4728,  7.3418,  6.3018,  6.4707,  5.2189,  5.4907,  4.8914,
#         9.322 ,  9.5962,  9.257 ,  9.6216,  9.3213,  9.6938, 10.1146,
#         9.6247,  9.7436,  8.8404,  6.987 ,  6.2594,  5.78  ,  6.1056,
#         5.705 ,  5.6982,  8.4335,  7.4843,  7.8957,  8.8738,  9.0385,
#         8.723 ,  7.6518,  7.9146,  8.0949,  8.5964,  8.0095,  5.8271,
#         4.9705,  6.462 ,  8.0445,  8.1877,  7.7711,  7.4725,  7.4537,
#         8.1157,  8.4174,  8.0381,  9.6674,  6.8137,  6.4119,  9.0936,
#         9.7934,  9.3126,  9.4595,  9.1482,  9.5858,  9.4475,  9.6676,
#         9.156 ,  8.7845,  8.2227,  8.1135,  8.2859,  8.1737,  8.4933,
#         7.9434,  8.4349,  8.028 ,  8.4836,  8.3699,  8.2766,  8.9186,
#         7.5525,  6.2959,  5.8549,  5.5354,  5.6742,  5.589 ,  6.1884,
#         7.0187,  7.1071,  6.1126,  6.066 ,  7.0028,  7.0257,  7.5499,
#         8.3969, 10.2461, 10.5027, 11.4631, 12.7023, 12.3174, 12.1575,
#        11.1318, 10.8344, 13.1327, 15.6097, 18.7204, 17.2139, 17.053 ,
#        14.4526, 13.8351, 14.0247, 14.394 , 13.5184, 14.1353, 16.5959,
#        15.5871, 15.9592, 15.1893, 14.3923, 14.2757, 14.4108, 14.429 ,
#        15.008 , 14.6784, 11.2466, 11.4687, 10.9782, 12.1372, 12.2231,
#        11.7857, 12.2716, 13.6613, 15.7537, 16.5631, 17.9568, 15.0312,
#        14.6677, 18.2834, 18.1382, 18.3011, 19.0406, 19.2266, 18.1282,
#        19.0009, 18.2802, 15.4621, 15.5162, 14.093 , 14.0753, 15.8015,
#        15.6749, 17.3466, 17.2245, 20.9442, 19.7599, 17.4309, 16.1856,
#        17.6665, 18.3675, 18.4878, 19.2323, 18.1625, 19.2148, 18.2354,
#        18.3477, 18.5432, 18.4632, 20.927 , 20.5076, 21.2801, 20.7179,
#        19.4938, 19.4136, 18.4281, 19.1721, 18.1911, 17.7927, 17.1644,
#        17.6245, 18.1699, 17.74  , 18.3312, 19.2283, 22.2835, 23.2444,
#        23.7849, 23.6838, 23.048 , 22.4763, 22.2001, 21.2774, 22.914 ,
#        22.0442, 20.7886, 20.2817, 19.8312, 20.1565, 21.8622, 21.2122,
#        22.4137, 24.2601, 24.0814, 24.6642, 25.0904, 24.1695, 22.0389,
#        22.093 , 22.9398, 23.288 , 23.829 , 24.7025, 25.052 , 25.6211,
#        24.0263, 25.6771, 26.0336, 26.4651, 27.083 , 27.1105, 25.4769,
#        25.6018, 25.0429, 24.7446, 24.4223, 23.693 , 20.217 , 19.5303,
#        19.8695, 19.388 , 20.2507, 23.5168, 24.3354, 22.0843, 20.894 ,
#        20.9747, 21.8169, 23.8788, 23.3682, 22.1338, 20.1864, 19.6008,
#        20.2806, 20.9316, 26.3738, 24.7924, 21.1684, 23.2211, 26.0232,
#        25.7268, 26.7893, 26.3236, 27.5237, 26.7615, 20.4203, 23.0587,
#        21.3141, 19.5829, 20.5587, 19.876 , 19.546 , 19.9402, 19.8078,
#        24.1176, 24.7925, 24.1794, 25.9305, 27.0687, 28.1412, 27.8342,
#        27.428 , 21.9572, 19.0744, 19.2006, 18.2919, 18.3065, 18.5841,
#        19.9462, 20.8302, 20.7231, 20.8684, 20.4858, 20.3419, 19.2633,
#        20.4381, 19.9213, 19.8687, 19.519 , 16.5686, 16.0529, 15.3955,
#        14.4037, 14.5007, 14.291 , 14.2266, 13.3582, 13.0484, 12.3038,
#        11.8358, 13.628 , 15.7851, 16.4384, 15.823 , 14.0574, 12.7626,
#        13.3388, 13.2105, 11.1665, 12.2455, 12.9526, 12.3593])

# %%
features.columns.tolist()
# Out:
# ['value_at_gentime__ar_coefficient__coeff_0__k_10',
#  'value_at_gentime__mean_change',
#  'value_at_gentime__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.0',
#  'value_at_gentime__time_reversal_asymmetry_statistic__lag_1',
#  'value_at_gentime__time_reversal_asymmetry_statistic__lag_2',
#  'value_at_gentime__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.0',
#  'value_at_gentime__time_reversal_asymmetry_statistic__lag_3',
#  'value_at_gentime__agg_linear_trend__attr_"rvalue"__chunk_len_50__f_agg_"mean"',
#  'value_at_gentime__mean_abs_change',
#  'value_at_gentime__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.0',
#  'value_at_gentime__absolute_sum_of_changes',
#  'value_at_gentime__agg_linear_trend__attr_"rvalue"__chunk_len_10__f_agg_"min"',
#  'value_at_gentime__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.2',
#  'value_at_gentime__agg_linear_trend__attr_"slope"__chunk_len_10__f_agg_"min"',
#  'value_at_gentime__agg_linear_trend__attr_"slope"__chunk_len_5__f_agg_"min"',
#  'value_at_gentime__abs_energy',
#  'value_at_gentime__root_mean_square',
#  'value_at_gentime__quantile__q_0.9',
#  'value_at_gentime__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"min"',
#  'value_at_gentime__index_mass_quantile__q_0.2',
#  'value_at_gentime__agg_linear_trend__attr_"rvalue"__chunk_len_10__f_agg_"mean"',
#  'value_at_gentime__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.0',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_0',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_0',
#  'value_at_gentime__mean',
#  'value_at_gentime__sum_values',
#  'value_at_gentime__cid_ce__normalize_False',
#  'value_at_gentime__c3__lag_1',
#  'value_at_gentime__minimum',
#  'value_at_gentime__index_mass_quantile__q_0.3',
#  'value_at_gentime__quantile__q_0.2',
#  'value_at_gentime__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"mean"',
#  'value_at_gentime__c3__lag_2',
#  'value_at_gentime__c3__lag_3',
#  'value_at_gentime__quantile__q_0.3',
#  'value_at_gentime__quantile__q_0.4',
#  'value_at_gentime__quantile__q_0.1',
#  'value_at_gentime__quantile__q_0.6',
#  'value_at_gentime__quantile__q_0.7',
#  'value_at_gentime__linear_trend__attr_"rvalue"',
#  'value_at_gentime__quantile__q_0.8',
#  'value_at_gentime__median',
#  'value_at_gentime__index_mass_quantile__q_0.1',
#  'value_at_gentime__index_mass_quantile__q_0.4',
#  'value_at_gentime__linear_trend__attr_"slope"',
#  'value_at_gentime__agg_linear_trend__attr_"slope"__chunk_len_5__f_agg_"mean"',
#  'value_at_gentime__agg_linear_trend__attr_"slope"__chunk_len_10__f_agg_"mean"',
#  'value_at_gentime__variation_coefficient',
#  'value_at_gentime__maximum',
#  'value_at_gentime__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"max"',
#  'value_at_gentime__energy_ratio_by_chunks__num_segments_10__segment_focus_0',
#  'value_at_gentime__agg_linear_trend__attr_"rvalue"__chunk_len_10__f_agg_"max"',
#  'value_at_gentime__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.4',
#  'value_at_gentime__agg_linear_trend__attr_"slope"__chunk_len_5__f_agg_"max"',
#  'value_at_gentime__agg_linear_trend__attr_"slope"__chunk_len_50__f_agg_"mean"',
#  'value_at_gentime__agg_linear_trend__attr_"slope"__chunk_len_10__f_agg_"max"',
#  'value_at_gentime__index_mass_quantile__q_0.6',
#  'value_at_gentime__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.2',
#  'value_at_gentime__energy_ratio_by_chunks__num_segments_10__segment_focus_9',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_1',
#  'value_at_gentime__count_below__t_0',
#  'value_at_gentime__range_count__max_1000000000000.0__min_0',
#  'value_at_gentime__count_above__t_0',
#  'value_at_gentime__number_crossing_m__m_-1',
#  'value_at_gentime__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.2',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_1',
#  'value_at_gentime__last_location_of_minimum',
#  'value_at_gentime__index_mass_quantile__q_0.7',
#  'value_at_gentime__first_location_of_minimum',
#  'value_at_gentime__index_mass_quantile__q_0.9',
#  'value_at_gentime__range_count__max_1__min_-1',
#  'value_at_gentime__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.0',
#  'value_at_gentime__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.0',
#  'value_at_gentime__agg_linear_trend__attr_"slope"__chunk_len_50__f_agg_"min"',
#  'value_at_gentime__number_crossing_m__m_0',
#  'value_at_gentime__number_crossing_m__m_1',
#  'value_at_gentime__agg_linear_trend__attr_"slope"__chunk_len_50__f_agg_"max"',
#  'value_at_gentime__last_location_of_maximum',
#  'value_at_gentime__first_location_of_maximum',
#  'value_at_gentime__max_langevin_fixed_point__m_3__r_30',
#  'value_at_gentime__index_mass_quantile__q_0.8',
#  'value_at_gentime__agg_autocorrelation__f_agg_"var"__maxlag_40',
#  'value_at_gentime__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.0',
#  'value_at_gentime__approximate_entropy__m_2__r_0.7',
#  'value_at_gentime__energy_ratio_by_chunks__num_segments_10__segment_focus_1',
#  'value_at_gentime__energy_ratio_by_chunks__num_segments_10__segment_focus_7',
#  'value_at_gentime__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.2',
#  'value_at_gentime__change_quantiles__f_agg_"mean"__isabs_False__qh_0.6__ql_0.0',
#  'value_at_gentime__energy_ratio_by_chunks__num_segments_10__segment_focus_8',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_2',
#  'value_at_gentime__autocorrelation__lag_2',
#  'value_at_gentime__agg_linear_trend__attr_"rvalue"__chunk_len_50__f_agg_"max"',
#  'value_at_gentime__cid_ce__normalize_True',
#  'value_at_gentime__approximate_entropy__m_2__r_0.9',
#  'value_at_gentime__autocorrelation__lag_1',
#  'value_at_gentime__partial_autocorrelation__lag_1',
#  'value_at_gentime__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.6',
#  'value_at_gentime__fourier_entropy__bins_100',
#  'value_at_gentime__fourier_entropy__bins_10',
#  'value_at_gentime__agg_linear_trend__attr_"rvalue"__chunk_len_50__f_agg_"min"',
#  'value_at_gentime__longest_strike_above_mean',
#  'value_at_gentime__autocorrelation__lag_3',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_3',
#  'value_at_gentime__fft_aggregated__aggtype_"centroid"',
#  'value_at_gentime__friedrich_coefficients__coeff_3__m_3__r_30',
#  'value_at_gentime__approximate_entropy__m_2__r_0.5',
#  'value_at_gentime__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.2',
#  'value_at_gentime__agg_linear_trend__attr_"stderr"__chunk_len_10__f_agg_"min"',
#  'value_at_gentime__change_quantiles__f_agg_"mean"__isabs_False__qh_0.4__ql_0.0',
#  'value_at_gentime__energy_ratio_by_chunks__num_segments_10__segment_focus_6',
#  'value_at_gentime__lempel_ziv_complexity__bins_3',
#  'value_at_gentime__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.4',
#  'value_at_gentime__fourier_entropy__bins_5',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_2',
#  'value_at_gentime__cwt_coefficients__coeff_0__w_10__widths_(2, 5, 10, 20)',
#  'value_at_gentime__autocorrelation__lag_4',
#  'value_at_gentime__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.8',
#  'value_at_gentime__lempel_ziv_complexity__bins_5',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_5',
#  'value_at_gentime__ar_coefficient__coeff_5__k_10',
#  'value_at_gentime__autocorrelation__lag_5',
#  'value_at_gentime__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.0',
#  'value_at_gentime__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.0',
#  'value_at_gentime__fft_aggregated__aggtype_"skew"',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_6',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_44',
#  'value_at_gentime__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.4',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_42',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_4',
#  'value_at_gentime__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2',
#  'value_at_gentime__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.0',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_33',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_41',
#  'value_at_gentime__energy_ratio_by_chunks__num_segments_10__segment_focus_2',
#  'value_at_gentime__approximate_entropy__m_2__r_0.1',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_3',
#  'value_at_gentime__cwt_coefficients__coeff_1__w_10__widths_(2, 5, 10, 20)',
#  'value_at_gentime__cwt_coefficients__coeff_0__w_20__widths_(2, 5, 10, 20)',
#  'value_at_gentime__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"max"',
#  'value_at_gentime__fourier_entropy__bins_3',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_38',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_8',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_7',
#  'value_at_gentime__augmented_dickey_fuller__attr_"pvalue"__autolag_"AIC"',
#  'value_at_gentime__augmented_dickey_fuller__attr_"teststat"__autolag_"AIC"',
#  'value_at_gentime__partial_autocorrelation__lag_6',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_16',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_37',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_35',
#  'value_at_gentime__autocorrelation__lag_6',
#  'value_at_gentime__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.2',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_27',
#  'value_at_gentime__friedrich_coefficients__coeff_2__m_3__r_30',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_39',
#  'value_at_gentime__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"var"',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_43',
#  'value_at_gentime__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"mean"',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_36',
#  'value_at_gentime__ar_coefficient__coeff_6__k_10',
#  'value_at_gentime__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"min"',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_10',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_40',
#  'value_at_gentime__longest_strike_below_mean',
#  'value_at_gentime__permutation_entropy__dimension_7__tau_1',
#  'value_at_gentime__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"var"',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_34',
#  'value_at_gentime__energy_ratio_by_chunks__num_segments_10__segment_focus_5',
#  'value_at_gentime__cwt_coefficients__coeff_1__w_20__widths_(2, 5, 10, 20)',
#  'value_at_gentime__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.4',
#  'value_at_gentime__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"var"',
#  'value_at_gentime__fft_aggregated__aggtype_"variance"',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_11',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_45',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_12',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_32',
#  'value_at_gentime__cwt_coefficients__coeff_2__w_10__widths_(2, 5, 10, 20)',
#  'value_at_gentime__autocorrelation__lag_7',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_9',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_40',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_25',
#  'value_at_gentime__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.4',
#  'value_at_gentime__permutation_entropy__dimension_6__tau_1',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_31',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_28',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_29',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_13',
#  'value_at_gentime__sample_entropy',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_16',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_26',
#  'value_at_gentime__lempel_ziv_complexity__bins_10',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_43',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_23',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_5',
#  'value_at_gentime__fourier_entropy__bins_2',
#  'value_at_gentime__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.0',
#  'value_at_gentime__change_quantiles__f_agg_"mean"__isabs_False__qh_0.6__ql_0.2',
#  'value_at_gentime__change_quantiles__f_agg_"mean"__isabs_False__qh_0.4__ql_0.2',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_30',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_25',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_30',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_17',
#  'value_at_gentime__agg_linear_trend__attr_"stderr"__chunk_len_10__f_agg_"mean"',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_27',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_20',
#  'value_at_gentime__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.6',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_7',
#  'value_at_gentime__cwt_coefficients__coeff_2__w_20__widths_(2, 5, 10, 20)',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_19',
#  'value_at_gentime__autocorrelation__lag_8',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_29',
#  'value_at_gentime__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.2',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_14',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_4',
#  'value_at_gentime__cwt_coefficients__coeff_3__w_10__widths_(2, 5, 10, 20)',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_15',
#  'value_at_gentime__permutation_entropy__dimension_5__tau_1',
#  'value_at_gentime__friedrich_coefficients__coeff_1__m_3__r_30',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_21',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_10',
#  'value_at_gentime__number_peaks__n_10',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_6',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_26',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_8',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_23',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_18',
#  'value_at_gentime__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.6',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_22',
#  'value_at_gentime__sum_of_reoccurring_data_points',
#  'value_at_gentime__cwt_coefficients__coeff_3__w_20__widths_(2, 5, 10, 20)',
#  'value_at_gentime__sum_of_reoccurring_values',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_15',
#  'value_at_gentime__ar_coefficient__coeff_1__k_10',
#  'value_at_gentime__partial_autocorrelation__lag_9',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_20',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_27',
#  'value_at_gentime__partial_autocorrelation__lag_2',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_23',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_9',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_26',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_19',
#  'value_at_gentime__cwt_coefficients__coeff_4__w_10__widths_(2, 5, 10, 20)',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_11',
#  'value_at_gentime__ar_coefficient__coeff_8__k_10',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_21',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_22',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_24',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_45',
#  'value_at_gentime__cwt_coefficients__coeff_0__w_5__widths_(2, 5, 10, 20)',
#  'value_at_gentime__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"min"',
#  'value_at_gentime__spkt_welch_density__coeff_2',
#  'value_at_gentime__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.6',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_2',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_28',
#  'value_at_gentime__autocorrelation__lag_9',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_16',
#  'value_at_gentime__cwt_coefficients__coeff_4__w_20__widths_(2, 5, 10, 20)',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_22',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_17',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_24',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_15',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_12',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_9',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_29',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_13',
#  'value_at_gentime__percentage_of_reoccurring_datapoints_to_all_datapoints',
#  'value_at_gentime__percentage_of_reoccurring_values_to_all_values',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_6',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_19',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_25',
#  'value_at_gentime__spkt_welch_density__coeff_8',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_33',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_26',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_28',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_1',
#  'value_at_gentime__ratio_value_number_to_time_series_length',
#  'value_at_gentime__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.4',
#  'value_at_gentime__change_quantiles__f_agg_"mean"__isabs_False__qh_0.6__ql_0.4',
#  'value_at_gentime__cwt_coefficients__coeff_5__w_10__widths_(2, 5, 10, 20)',
#  'value_at_gentime__partial_autocorrelation__lag_5',
#  'value_at_gentime__ar_coefficient__coeff_2__k_10',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_30',
#  'value_at_gentime__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"mean"',
#  'value_at_gentime__ratio_beyond_r_sigma__r_3',
#  'value_at_gentime__number_peaks__n_5',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_31',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_20',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_14',
#  'value_at_gentime__cwt_coefficients__coeff_5__w_20__widths_(2, 5, 10, 20)',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_11',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_22',
#  'value_at_gentime__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.2',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_1',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_32',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_21',
#  'value_at_gentime__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.2',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_8',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_16',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_37',
#  'value_at_gentime__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.8',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_3',
#  'value_at_gentime__cwt_coefficients__coeff_1__w_5__widths_(2, 5, 10, 20)',
#  'value_at_gentime__change_quantiles__f_agg_"mean"__isabs_False__qh_0.2__ql_0.0',
#  'value_at_gentime__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.6',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_17',
#  'value_at_gentime__value_count__value_0',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_23',
#  'value_at_gentime__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.0',
#  'value_at_gentime__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.4',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_31',
#  'value_at_gentime__approximate_entropy__m_2__r_0.3',
#  'value_at_gentime__cwt_coefficients__coeff_6__w_10__widths_(2, 5, 10, 20)',
#  'value_at_gentime__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.2',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_18',
#  'value_at_gentime__cwt_coefficients__coeff_6__w_20__widths_(2, 5, 10, 20)',
#  'value_at_gentime__energy_ratio_by_chunks__num_segments_10__segment_focus_3',
#  'value_at_gentime__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.0',
#  'value_at_gentime__number_peaks__n_3',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_24',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_18',
#  'value_at_gentime__linear_trend__attr_"pvalue"',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_27',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_35',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_34',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_20',
#  'value_at_gentime__ar_coefficient__coeff_9__k_10',
#  'value_at_gentime__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"max"',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_28',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_33',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_15',
#  'value_at_gentime__cwt_coefficients__coeff_7__w_10__widths_(2, 5, 10, 20)',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_31',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_33',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_24',
#  'value_at_gentime__cwt_coefficients__coeff_7__w_20__widths_(2, 5, 10, 20)',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_12',
#  'value_at_gentime__agg_linear_trend__attr_"stderr"__chunk_len_10__f_agg_"var"',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_25',
#  'value_at_gentime__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.2',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_13',
#  'value_at_gentime__cwt_coefficients__coeff_2__w_5__widths_(2, 5, 10, 20)',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_36',
#  'value_at_gentime__skewness',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_29',
#  'value_at_gentime__number_peaks__n_1',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_32',
#  'value_at_gentime__cwt_coefficients__coeff_8__w_10__widths_(2, 5, 10, 20)',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_14',
#  'value_at_gentime__agg_linear_trend__attr_"stderr"__chunk_len_10__f_agg_"max"',
#  'value_at_gentime__cwt_coefficients__coeff_8__w_20__widths_(2, 5, 10, 20)',
#  'value_at_gentime__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.2',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_10',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_11',
#  'value_at_gentime__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"max"',
#  'value_at_gentime__mean_second_derivative_central',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_37',
#  'value_at_gentime__permutation_entropy__dimension_4__tau_1',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_13',
#  'value_at_gentime__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"mean"',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_45',
#  'value_at_gentime__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.0',
#  'value_at_gentime__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.4',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_2',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_30',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_4',
#  'value_at_gentime__cwt_coefficients__coeff_9__w_10__widths_(2, 5, 10, 20)',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_38',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_36',
#  'value_at_gentime__agg_autocorrelation__f_agg_"mean"__maxlag_40',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_17',
#  'value_at_gentime__cwt_coefficients__coeff_9__w_20__widths_(2, 5, 10, 20)',
#  'value_at_gentime__linear_trend__attr_"stderr"',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_10',
#  'value_at_gentime__matrix_profile__feature_"25"__threshold_0.98',
#  'value_at_gentime__has_duplicate',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_42',
#  'value_at_gentime__partial_autocorrelation__lag_4',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_19',
#  'value_at_gentime__permutation_entropy__dimension_3__tau_1',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_35',
#  'value_at_gentime__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.8',
#  'value_at_gentime__cwt_coefficients__coeff_0__w_2__widths_(2, 5, 10, 20)',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_8',
#  'value_at_gentime__partial_autocorrelation__lag_7',
#  'value_at_gentime__matrix_profile__feature_"75"__threshold_0.98',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_34',
#  'value_at_gentime__cwt_coefficients__coeff_10__w_10__widths_(2, 5, 10, 20)',
#  'value_at_gentime__lempel_ziv_complexity__bins_100',
#  'value_at_gentime__standard_deviation',
#  'value_at_gentime__variance',
#  'value_at_gentime__cwt_coefficients__coeff_3__w_5__widths_(2, 5, 10, 20)',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_37',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_39',
#  'value_at_gentime__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"max"',
#  'value_at_gentime__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"mean"',
#  'value_at_gentime__ar_coefficient__coeff_4__k_10',
#  'value_at_gentime__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"min"',
#  'value_at_gentime__has_duplicate_min',
#  'value_at_gentime__lempel_ziv_complexity__bins_2',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_38',
#  'value_at_gentime__cwt_coefficients__coeff_11__w_10__widths_(2, 5, 10, 20)',
#  'value_at_gentime__cwt_coefficients__coeff_10__w_20__widths_(2, 5, 10, 20)',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_41',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_18',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_38',
#  'value_at_gentime__fft_aggregated__aggtype_"kurtosis"',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_34',
#  'value_at_gentime__matrix_profile__feature_"mean"__threshold_0.98',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_7',
#  'value_at_gentime__large_standard_deviation__r_0.25',
#  'value_at_gentime__large_standard_deviation__r_0.2',
#  'value_at_gentime__ar_coefficient__coeff_3__k_10',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_40',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_44',
#  'value_at_gentime__matrix_profile__feature_"median"__threshold_0.98',
#  'value_at_gentime__cwt_coefficients__coeff_12__w_10__widths_(2, 5, 10, 20)',
#  'value_at_gentime__fft_coefficient__attr_"angle"__coeff_39',
#  'value_at_gentime__count_above_mean',
#  'value_at_gentime__count_below_mean',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_6',
#  'value_at_gentime__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.2',
#  'value_at_gentime__linear_trend__attr_"intercept"',
#  'value_at_gentime__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.6',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_5',
#  'value_at_gentime__cwt_coefficients__coeff_4__w_5__widths_(2, 5, 10, 20)',
#  'value_at_gentime__cwt_coefficients__coeff_11__w_20__widths_(2, 5, 10, 20)',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_4',
#  'value_at_gentime__ar_coefficient__coeff_7__k_10',
#  'value_at_gentime__fft_coefficient__attr_"abs"__coeff_5',
#  'value_at_gentime__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"min"',
#  'value_at_gentime__fft_coefficient__attr_"imag"__coeff_41',
#  'value_at_gentime__fft_coefficient__attr_"real"__coeff_9',
#  'value_at_gentime__cwt_coefficients__coeff_13__w_10__widths_(2, 5, 10, 20)',
#  'value_at_gentime__change_quantiles__f_agg_"var"__isabs_False__qh_0.2__ql_0.0',
#  'value_at_gentime__number_cwt_peaks__n_5',
#  'value_at_gentime__ratio_beyond_r_sigma__r_2',
#  'value_at_gentime__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.4']

# %% [markdown]
# https://habr.com/ru/post/428213/

# %% [markdown]
# https://github.com/slundberg/shap

# %%
import shap

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
explainer = shap.Explainer(clf)

# %%
shap_values_train = explainer.shap_values(X_train)

# %%
shap_values_test = explainer.shap_values(X_test)

# %% [markdown]
# To get an overview of which features are most important for a model we can plot the SHAP values of every feature for every sample. The plot below sorts features by the sum of SHAP value magnitudes over all samples, and uses SHAP values to show the distribution of the impacts each feature has on the model output. The color represents the feature value (red high, blue low).

# %%
shap.summary_plot(shap_values_train, X_train,max_display=5)

# %%
shap.summary_plot(shap_values_test, X_test,max_display=5)

# %% [markdown]
# https://www.kaggle.com/wrosinski/shap-feature-importance-with-feature-engineering

# %%
shap_sum = np.abs(shap_values_test).mean(axis=0)
importance_df = pd.DataFrame([X_test.columns.tolist(), shap_sum.tolist()]).T
importance_df.columns = ['column_name', 'shap_importance']
importance_df = importance_df.sort_values('shap_importance', ascending=False)
importance_df
# Out:
#                                            column_name shap_importance
# 3    value_at_gentime__time_reversal_asymmetry_stat...         2.47273
# 4    value_at_gentime__time_reversal_asymmetry_stat...        0.819601
# 27                         value_at_gentime__c3__lag_1        0.702659
# 28                           value_at_gentime__minimum        0.383994
# 9    value_at_gentime__change_quantiles__f_agg_"mea...        0.365605
# ..                                                 ...             ...
# 373                    value_at_gentime__has_duplicate     0.000136401
# 408  value_at_gentime__large_standard_deviation__r_...     9.08596e-05
# 396                value_at_gentime__has_duplicate_min     8.71206e-05
# 304             value_at_gentime__value_count__value_0     5.94825e-05
# 397    value_at_gentime__lempel_ziv_complexity__bins_2     3.40156e-05
#
# [436 rows x 2 columns]

# %%
shap_values_train
# Out:
# array([[-0.01350001, -0.00670756,  0.01352863, ..., -0.00161539,
#         -0.00050102,  0.00193775],
#        [-0.01285038, -0.01174094,  0.08343724, ..., -0.00137912,
#         -0.00038227,  0.00102487],
#        [-0.01215741,  0.01592733, -0.01750409, ..., -0.00313726,
#         -0.00040966,  0.00060678],
#        ...,
#        [ 0.01415032,  0.21250262,  0.25143409, ..., -0.00101642,
#         -0.00060179, -0.00736127],
#        [ 0.01777122,  0.23349341,  0.25072736, ..., -0.00192503,
#         -0.00055097, -0.00943266],
#        [ 0.02082372,  0.33741169,  0.35311448, ..., -0.00186887,
#         -0.00066351, -0.00361829]])

# %%
train_pred[0], y_train.iloc[0]
# Out:
# (2.1460000000000012, 2.21)

# %%
shap.plots.force(explainer.expected_value, shap_values_train[0])
# Out:
# <div id='i2J8A0IBU6E94CIA4B71B'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 15.451417000000003, "outValue": 2.1460000000000097, "link": "identity", "featureNames": ["Feature 0", "Feature 1", "Feature 2", "Feature 3", "Feature 4", "Feature 5", "Feature 6", "Feature 7", "Feature 8", "Feature 9", "Feature 10", "Feature 11", "Feature 12", "Feature 13", "Feature 14", "Feature 15", "Feature 16", "Feature 17", "Feature 18", "Feature 19", "Feature 20", "Feature 21", "Feature 22", "Feature 23", "Feature 24", "Feature 25", "Feature 26", "Feature 27", "Feature 28", "Feature 29", "Feature 30", "Feature 31", "Feature 32", "Feature 33", "Feature 34", "Feature 35", "Feature 36", "Feature 37", "Feature 38", "Feature 39", "Feature 40", "Feature 41", "Feature 42", "Feature 43", "Feature 44", "Feature 45", "Feature 46", "Feature 47", "Feature 48", "Feature 49", "Feature 50", "Feature 51", "Feature 52", "Feature 53", "Feature 54", "Feature 55", "Feature 56", "Feature 57", "Feature 58", "Feature 59", "Feature 60", "Feature 61", "Feature 62", "Feature 63", "Feature 64", "Feature 65", "Feature 66", "Feature 67", "Feature 68", "Feature 69", "Feature 70", "Feature 71", "Feature 72", "Feature 73", "Feature 74", "Feature 75", "Feature 76", "Feature 77", "Feature 78", "Feature 79", "Feature 80", "Feature 81", "Feature 82", "Feature 83", "Feature 84", "Feature 85", "Feature 86", "Feature 87", "Feature 88", "Feature 89", "Feature 90", "Feature 91", "Feature 92", "Feature 93", "Feature 94", "Feature 95", "Feature 96", "Feature 97", "Feature 98", "Feature 99", "Feature 100", "Feature 101", "Feature 102", "Feature 103", "Feature 104", "Feature 105", "Feature 106", "Feature 107", "Feature 108", "Feature 109", "Feature 110", "Feature 111", "Feature 112", "Feature 113", "Feature 114", "Feature 115", "Feature 116", "Feature 117", "Feature 118", "Feature 119", "Feature 120", "Feature 121", "Feature 122", "Feature 123", "Feature 124", "Feature 125", "Feature 126", "Feature 127", "Feature 128", "Feature 129", "Feature 130", "Feature 131", "Feature 132", "Feature 133", "Feature 134", "Feature 135", "Feature 136", "Feature 137", "Feature 138", "Feature 139", "Feature 140", "Feature 141", "Feature 142", "Feature 143", "Feature 144", "Feature 145", "Feature 146", "Feature 147", "Feature 148", "Feature 149", "Feature 150", "Feature 151", "Feature 152", "Feature 153", "Feature 154", "Feature 155", "Feature 156", "Feature 157", "Feature 158", "Feature 159", "Feature 160", "Feature 161", "Feature 162", "Feature 163", "Feature 164", "Feature 165", "Feature 166", "Feature 167", "Feature 168", "Feature 169", "Feature 170", "Feature 171", "Feature 172", "Feature 173", "Feature 174", "Feature 175", "Feature 176", "Feature 177", "Feature 178", "Feature 179", "Feature 180", "Feature 181", "Feature 182", "Feature 183", "Feature 184", "Feature 185", "Feature 186", "Feature 187", "Feature 188", "Feature 189", "Feature 190", "Feature 191", "Feature 192", "Feature 193", "Feature 194", "Feature 195", "Feature 196", "Feature 197", "Feature 198", "Feature 199", "Feature 200", "Feature 201", "Feature 202", "Feature 203", "Feature 204", "Feature 205", "Feature 206", "Feature 207", "Feature 208", "Feature 209", "Feature 210", "Feature 211", "Feature 212", "Feature 213", "Feature 214", "Feature 215", "Feature 216", "Feature 217", "Feature 218", "Feature 219", "Feature 220", "Feature 221", "Feature 222", "Feature 223", "Feature 224", "Feature 225", "Feature 226", "Feature 227", "Feature 228", "Feature 229", "Feature 230", "Feature 231", "Feature 232", "Feature 233", "Feature 234", "Feature 235", "Feature 236", "Feature 237", "Feature 238", "Feature 239", "Feature 240", "Feature 241", "Feature 242", "Feature 243", "Feature 244", "Feature 245", "Feature 246", "Feature 247", "Feature 248", "Feature 249", "Feature 250", "Feature 251", "Feature 252", "Feature 253", "Feature 254", "Feature 255", "Feature 256", "Feature 257", "Feature 258", "Feature 259", "Feature 260", "Feature 26 ...

# %%
shap.plots.force(explainer.expected_value, shap_values_test[0])
# Out:
# <div id='iJKBR2X3ZLJT3Y35N65R0'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 15.451417000000003, "outValue": 7.472799999999984, "link": "identity", "featureNames": ["Feature 0", "Feature 1", "Feature 2", "Feature 3", "Feature 4", "Feature 5", "Feature 6", "Feature 7", "Feature 8", "Feature 9", "Feature 10", "Feature 11", "Feature 12", "Feature 13", "Feature 14", "Feature 15", "Feature 16", "Feature 17", "Feature 18", "Feature 19", "Feature 20", "Feature 21", "Feature 22", "Feature 23", "Feature 24", "Feature 25", "Feature 26", "Feature 27", "Feature 28", "Feature 29", "Feature 30", "Feature 31", "Feature 32", "Feature 33", "Feature 34", "Feature 35", "Feature 36", "Feature 37", "Feature 38", "Feature 39", "Feature 40", "Feature 41", "Feature 42", "Feature 43", "Feature 44", "Feature 45", "Feature 46", "Feature 47", "Feature 48", "Feature 49", "Feature 50", "Feature 51", "Feature 52", "Feature 53", "Feature 54", "Feature 55", "Feature 56", "Feature 57", "Feature 58", "Feature 59", "Feature 60", "Feature 61", "Feature 62", "Feature 63", "Feature 64", "Feature 65", "Feature 66", "Feature 67", "Feature 68", "Feature 69", "Feature 70", "Feature 71", "Feature 72", "Feature 73", "Feature 74", "Feature 75", "Feature 76", "Feature 77", "Feature 78", "Feature 79", "Feature 80", "Feature 81", "Feature 82", "Feature 83", "Feature 84", "Feature 85", "Feature 86", "Feature 87", "Feature 88", "Feature 89", "Feature 90", "Feature 91", "Feature 92", "Feature 93", "Feature 94", "Feature 95", "Feature 96", "Feature 97", "Feature 98", "Feature 99", "Feature 100", "Feature 101", "Feature 102", "Feature 103", "Feature 104", "Feature 105", "Feature 106", "Feature 107", "Feature 108", "Feature 109", "Feature 110", "Feature 111", "Feature 112", "Feature 113", "Feature 114", "Feature 115", "Feature 116", "Feature 117", "Feature 118", "Feature 119", "Feature 120", "Feature 121", "Feature 122", "Feature 123", "Feature 124", "Feature 125", "Feature 126", "Feature 127", "Feature 128", "Feature 129", "Feature 130", "Feature 131", "Feature 132", "Feature 133", "Feature 134", "Feature 135", "Feature 136", "Feature 137", "Feature 138", "Feature 139", "Feature 140", "Feature 141", "Feature 142", "Feature 143", "Feature 144", "Feature 145", "Feature 146", "Feature 147", "Feature 148", "Feature 149", "Feature 150", "Feature 151", "Feature 152", "Feature 153", "Feature 154", "Feature 155", "Feature 156", "Feature 157", "Feature 158", "Feature 159", "Feature 160", "Feature 161", "Feature 162", "Feature 163", "Feature 164", "Feature 165", "Feature 166", "Feature 167", "Feature 168", "Feature 169", "Feature 170", "Feature 171", "Feature 172", "Feature 173", "Feature 174", "Feature 175", "Feature 176", "Feature 177", "Feature 178", "Feature 179", "Feature 180", "Feature 181", "Feature 182", "Feature 183", "Feature 184", "Feature 185", "Feature 186", "Feature 187", "Feature 188", "Feature 189", "Feature 190", "Feature 191", "Feature 192", "Feature 193", "Feature 194", "Feature 195", "Feature 196", "Feature 197", "Feature 198", "Feature 199", "Feature 200", "Feature 201", "Feature 202", "Feature 203", "Feature 204", "Feature 205", "Feature 206", "Feature 207", "Feature 208", "Feature 209", "Feature 210", "Feature 211", "Feature 212", "Feature 213", "Feature 214", "Feature 215", "Feature 216", "Feature 217", "Feature 218", "Feature 219", "Feature 220", "Feature 221", "Feature 222", "Feature 223", "Feature 224", "Feature 225", "Feature 226", "Feature 227", "Feature 228", "Feature 229", "Feature 230", "Feature 231", "Feature 232", "Feature 233", "Feature 234", "Feature 235", "Feature 236", "Feature 237", "Feature 238", "Feature 239", "Feature 240", "Feature 241", "Feature 242", "Feature 243", "Feature 244", "Feature 245", "Feature 246", "Feature 247", "Feature 248", "Feature 249", "Feature 250", "Feature 251", "Feature 252", "Feature 253", "Feature 254", "Feature 255", "Feature 256", "Feature 257", "Feature 258", "Feature 259", "Feature 260", "Feature 261 ...

# %%
test_pred[0], y_test.iloc[0]
# Out:
# (7.472800000000001, 2.72)

# %%
importance_df.column_name[0:10].values.tolist()
# Out:
# ['value_at_gentime__time_reversal_asymmetry_statistic__lag_1',
#  'value_at_gentime__time_reversal_asymmetry_statistic__lag_2',
#  'value_at_gentime__c3__lag_1',
#  'value_at_gentime__minimum',
#  'value_at_gentime__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.0',
#  'value_at_gentime__mean_abs_change',
#  'value_at_gentime__absolute_sum_of_changes',
#  'value_at_gentime__time_reversal_asymmetry_statistic__lag_3',
#  'value_at_gentime__energy_ratio_by_chunks__num_segments_10__segment_focus_9',
#  'value_at_gentime__agg_linear_trend__attr_"slope"__chunk_len_50__f_agg_"min"']

# %%
top_fstr_shap_slice = importance_df.column_name[0:10].values.tolist()
clf_top_fstr_shap = RandomForestRegressor(random_state=42)
clf_top_fstr_shap.fit(X_train[top_fstr_shap_slice], y_train)
clf_top_fstr_shap_train_pred = clf_top_fstr_shap.predict(X_train[top_fstr_shap_slice])
clf_top_fstr_shap_test_pred = clf_top_fstr_shap.predict(X_test[top_fstr_shap_slice])

clf_top_fstr_shap_train_q =  quality(
    df=pd.DataFrame(
        {"clf_top_fstr_shap_train_pred": clf_top_fstr_shap_train_pred, "target_value": y_train}
    ), pred_name="clf_top_fstr_shap_train_pred", target_name="target_value")


clf_top_fstr_shap_test_q =  quality(
    df=pd.DataFrame(
        {"clf_top_fstr_shap_test_pred": clf_top_fstr_shap_test_pred, "target_value": y_test}
    ), pred_name="clf_top_fstr_shap_test_pred", target_name="target_value")

# %%
clf_top_fstr_shap_train_q
# Out:
# Namespace(mae=0.9986592000000001, mape=0.06440029251192682, median_ae=0.7829000000000086, prediction_name='clf_top_fstr_shap_train_pred', rmse=1.3035640974574285)

# %%
clf_train_q
# Out:
# Namespace(mae=0.9760635, mape=0.0629431691113596, median_ae=0.7779499999999944, prediction_name='train_pred', rmse=1.247629938920191)

# %%
clf_top_fstr_shap_test_q
# Out:
# Namespace(mae=3.6726346666666676, mape=0.232415812344429, median_ae=3.4514, prediction_name='clf_top_fstr_shap_test_pred', rmse=4.516623404646441)

# %%
clf_test_q
# Out:
# Namespace(mae=3.5115030000000003, mape=0.22221889634223516, median_ae=3.342999999999998, prediction_name='test_pred', rmse=4.207101022640175)

# %%
plt.plot(train_pred)
plt.plot(clf_top_fstr_shap_train_pred)
plt.plot(y_train_inertial.values)
plt.plot(y_train.values)

# %%
plt.plot(test_pred, label="full features")
plt.plot(clf_top_fstr_shap_test_pred, label="top 10 shap fstr features")
plt.plot(y_test_inertial.values, label="inertial")
plt.plot(y_test.values, label="target")

plt.legend()
